# %%
from wikiparser_utils import WikiXMLDump

# %%
dump = WikiXMLDump('history.xml')
wind_turbine_page = dump.get_exact_page(20541773)
# Out:
# 7605it [00:46, 161.95it/s]

# %%
page_revisions = wind_turbine_page.get_revision()
rev_list = list(page_revisions)

# %%
for rev_id in rev_list[-5:]:
    rev = page_revisions[rev_id]
    print(rev.title, rev.page_id, rev.revision_id, rev.comment, '\n')
# Out:
# Wind turbine 20541773 1091089025 Alter: title. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Whoop whoop pull up | #UCB_webform 891/2092
#
# Wind turbine 20541773 1091253096 Rescuing 1 sources and tagging 1 as dead.) #IABot (v2.0.8.8) ([[User:Whoop whoop pull up|Whoop whoop pull up]] - 10050
#
# Wind turbine 20541773 1094598488 None
#
# Wind turbine 20541773 1095477036 Rescuing 4 sources and tagging 0 as dead.) #IABot (v2.0.8.8) ([[User:Mako001|Mako001]] - 10222
#
# Wind turbine 20541773 1095572402 /* Non-blade materials */C/E: "an greater" => "a greater"

# %%
last_revision = page_revisions[rev_list[-1]]
last_revision.get_links()
# Out:
# [('World wind capacity at 650,8 GW, Corona crisis will slow down markets in 2020, renewables to be core of economic stimulus programmes ',
#   'https://wwindea.org/world-wind-capacity-at-650-gw/'),
#  ('Islamic Technology: An Illustrated History',
#   'https://archive.org/details/islamictechnolog0000hasa/page/54}}</ref>'),
#  ('',
#   'https://web.archive.org/web/20071225091836/http://home.swipnet.se/islam/articles/HistoryofSciences.htm'),
#  ('A Wind Energy Pioneer: Charles F. Brush ',
#   'http://www.windpower.org/en/pictures/brush.htm'),
#  ('A Wind Energy Pioneer: Charles F. Brush ',
#   'https://web.archive.org/web/20080908061207/http://www.windpower.org/en/pictures/brush.htm'),
#  ('Quirky old-style contraptions make water from wind on the mesas of West Texas ',
#   'http://www.mysanantonio.com/news/weather/weatherwise/stories/MYSA092407.01A.State_windmills.3430a27.html'),
#  ('Quirky old-style contraptions make water from wind on the mesas of West Texas ',
# ...

# %%
last_revision.get_sections()
# Out:
# [(None,
# ...

# %%
last_revision.get_clean_sections()
# Out:
# [(None,
# ...

# %%
last_revision.get_plain_text()
# Out:
# '\n\n\n\n\nA wind turbine is a device that converts the kinetic energy of wind into electrical energy. Hundreds of thousands of large turbines, in installations known as wind farms, now generate over 650 gigawatts of power, with 60 GW added each year. Wind turbines are an increasingly important source of intermittent renewable energy, and are used in many countries to lower energy costs and reduce reliance on fossil fuels. One study claimed that,  wind had the "lowest relative greenhouse gas emissions, the least water consumption demands and, the most favorable social impacts" compared to photovoltaic, hydro, geothermal, coal and gas energy sources.\n\nSmaller wind turbines are used for applications such as battery charging for auxiliary power for boats or caravans, and to power traffic warning signs. Larger turbines can contribute to a domestic power supply while selling unused power back to the utility supplier via the electrical grid.\n\nWind turbines are manufactured in a wide ra
# ...
